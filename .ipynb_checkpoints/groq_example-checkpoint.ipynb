# %%
import os
from groq import Groq

api_key = os.getenv("GROQ_API_KEY")

if not api_key:
    print("Error: GROQ_API_KEY environment variable not set.")
    exit()

client = Groq(api_key=api_key)

def query_groq(prompt):
    try:
        response = client.chat.completions.create(
            model="llama-3.1-8b-instant",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=500,
            temperature=0.7
        )

        return response.choices[0].message.content

    except Exception as e:
        return f"Error: {str(e)}"


def main():
    print("Groq API Query Program")
    print("----------------------")

    user_prompt = input("Enter your prompt: ")

    print("\nQuerying Groq...\n")

    result = query_groq(user_prompt)

    print("Response:")
    print(result)


if __name__ == "__main__":
    main()
# Out:
# Groq API Query Program
# ----------------------
# Enter your prompt:  Explain artificial intelligence in simple words
# Querying Groq...
#
# Response:
# Artificial intelligence (AI) is a way to make machines think and act like humans. It's like teaching a computer to learn, reason, and make decisions on its own.
#
# Imagine you have a smartphone that can:
#
# 1. **Recognize pictures**: It can identify objects, people, and things in photos.
# 2. **Talk to you**: It can understand your voice and respond accordingly.
# 3. **Play games**: It can play games like chess, Sudoku, or even video games.
# 4. **Learn from you**: It can learn from your actions, preferences, and behavior.
#
# AI is like a super-smart computer program that can do all these things and more. It uses data and algorithms (step-by-step instructions) to make decisions, solve problems, and perform tasks.
#
# There are different types of AI, including:
#
# 1. **Narrow AI**: It's designed to perform a specific task, like image recognition or language translation.
# 2. **General AI**: It's like a human brain, capable of learning, reasoning, and making decisions in any situation.
# 3. **Super AI**: It's like a super-intelligent being, far beyond human capabilities.
#
# AI is used in many areas, such as:
#
# 1. **Virtual assistants**: Siri, Alexa, and Google Assistant.
# 2. **Self-driving cars**: Cars that can drive themselves without human input.
# 3. **Healthcare**: AI helps doctors diagnose diseases and develop new treatments.
# 4. **Customer service**: AI-powered chatbots help with customer support.
#
# In simple words, AI is like a smart machine that can think, learn, and act like humans, making our lives easier, safer, and more convenient.
